# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/roisin/.pyenv/versions/3.10.6/envs/ai_weeder/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/roisin/.pyenv/versions/3.10.6/envs/ai_weeder/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/roisin/code/dorwein/ai_weeder/raw_data/images/Common wheat/1.png', 0)
plt.imshow(img)

# %%
np.shape(img)[0]
# Out:
# 66

# %%
def resize_img(img,
                out_height = 128,    # default, can alter
                out_width = 128):     # default, can alter
    """
    Reshapes an image to desired dimensions
    """

    img = np.array(img)
    dims = np.shape(img)

    if dims[0]*dims[1] > out_height*out_width:
        img = cv2.resize(img, dsize=(out_height, out_width), interpolation=cv2.INTER_AREA)
    elif dims[0]*dims[1] < out_height*out_width:
        img = cv2.resize(img, dsize=(out_height, out_width), interpolation=cv2.INTER_LINEAR)
    else:
        pass

    return img

# %%
test = resize_img(img, 60, 40)

# %%
np.shape(test)
# Out:
# (40, 60)

# %%
plt.imshow(test)

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

def vgg16_preproc(img):
    '''
    Implements VGG16 processing function
    '''
    img = preprocess_input(img)

    return img
# Out:
# 2024-09-05 14:06:29.356656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-05 14:06:29.513873: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/roisin/.pyenv/versions/3.10.6/envs/ai_weeder/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/lib:/home/roisin/software/heasoft-6.31.1src/heasoft-6.31.1/x86_64-pc-linux-gnu-libc2.35/lib
# 2024-09-05 14:06:29.513899: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-09-05 14:06:29.546004: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-05 14:06:30.460982: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/roisin/.pyenv/versions/3.10.6/envs/ai_weeder/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/lib:/home/roisin/software/heasoft-6.31.1src/heasoft-6.31.1/x86_64-pc-linux-gnu-libc2.35/lib
# 2024-09-05 14:06:30.461064: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/roisin/.pyenv/versions/3.10.6/envs/ai_weeder/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/lib:/home/roisin/software/heasoft-6.31.1src/heasoft-6.31.1/x86_64-pc-linux-gnu-libc2.35/lib
# 2024-09-05 14:06:30.461074: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
vg=vgg16_preproc(test)

# %%
np.shape(vg)
# Out:
# (40, 60)
